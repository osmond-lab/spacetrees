# %%
import numpy as np
from tsconvert import from_newick
from utils import get_shared_times
from tqdm import tqdm

# %%
input = 'data/SGDP_aDNA_new_chr2_1locus_10M.newick'
output_stss = 'data/SGDP_aDNA_new_chr2_1locus_10M.stss'
output_ctss = 'data/SGDP_aDNA_new_chr2_1locus_10M.ctss'

with open(input, mode='r') as f:
      
      # open files to append to
      with open(output_stss, 'a') as stss:
        with open(output_ctss, 'a') as ctss:

          next(f) #skip header
          for line in f:
            # import tree
            string = line.split()[4] #extract newick string only (Relate adds some info beforehand)
            ts = from_newick(string, min_edge_length=1e-6) #convert to tskit "tree sequence" (only one tree)
            tree = ts.first() #the only tree
            print(tree)
# Out:
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1361831.7║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1345082.6║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1361466.3║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1329954.1║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1305241.2║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1269436.6║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1345632.6║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1312876.6║
# ╚═══════════════════╧═════════╝
#
# ╔═════════════════════════════╗
# ║Tree                         ║
# ╠═══════════════════╤═════════╣
# ║Index              │        0║
# ╟───────────────────┼─────────╢
# ║Interval           │  0-1 (1)║
# ╟───────────────────┼─────────╢
# ║Roots              │        1║
# ╟───────────────────┼─────────╢
# ║Nodes              │     7335║
# ╟───────────────────┼─────────╢
# ║Sites              │        0║
# ╟───────────────────┼─────────╢
# ║Mutations          │        0║
# ╟───────────────────┼─────────╢
# ║Total Branch Length│1221226.2║
# ╚═══════════════════╧═════════╝
#
# ╔═══════════════════════════╗
# ║Tree                       ║
# ╠═══════════════════╤═══════╣
# ║Index              │      0║
# ╟───────────────────┼───────╢
# ║Interval           │0-1 (1)║
# ╟───────────────────┼───────╢
# ║Roots              │      1║
# ╟───────────────────┼───────╢
# ║Nodes              │   7335║
# ╟───────────────────┼───────╢
# ║Sites              │      0║
# ╟───────────────────┼───────╢
# ║Mutations          │      0║
# ╟───────────────────┼───────╢
# ║Total Branch Length│1312760║
# ╚═══════════════════╧═══════╝

# %%
import sys
print("Recursion limit:", sys.getrecursionlimit())
# Out:
# Recursion limit: 3000
